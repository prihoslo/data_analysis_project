# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import defs
import re

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_colwidth', 20)

# %% [markdown]
# ## File dowload

# %%
df = pd.read_csv('../data/_data.csv', encoding='utf-8')
df.head(5)
# Out:
#    Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0           0       271271157                 4  Квартира
# 1           1       271634126                 4  Квартира
# 2           2       271173086   4, Оба варианта  Квартира
# 3           3       272197456   4, Оба варианта  Квартира
# 4           4       273614615                 2  Квартира
#
#                  Метро                Адрес      Площадь, м2  \
# 0  м. Смоленская (9...  Москва, улица Но...       200.0/20.0
# 1  м. Смоленская (8...  Москва, улица Но...  198.0/95.0/18.0
# 2  м. Смоленская (7...  Москва, улица Но...  200.0/116.0/4.0
# 3  м. Смоленская (3...  Москва, переулок...  170.0/95.0/17.0
# 4  м. Арбатская (7 ...  Москва, улица Но...    58.0/38.0/5.0
#
#                    Дом   Парковка                 Цена             Телефоны  \
# 0     5/16, Монолитный  подземная  500000.0 руб./ З...         +79166369231
# 1  5/16, Монолитно-...  подземная  500000.0 руб./ З...         +79850608590
# 2                 5/16  подземная  500000.0 руб./ З...  +79672086536, +7...
# 3                  5/6  подземная  400000.0 руб./ З...  +79660342340, +7...
# 4     12/26, Панельный        NaN  225000.0 руб./ З...         +79852432860
#
#               Описание        Ремонт Площадь комнат, м2 Балкон  \
# 0  Без комиссии для...  Дизайнерский                NaN    NaN
# 1  Лот 93107. Елена...  Дизайнерский        25 25 20 25    NaN
# 2  ID 36380:  Шикар...    Евроремонт                NaN    NaN
# 3  ID 31618:  Экскл...    Евроремонт        14-42-20-19    NaN
# 4  Лот 111542. Тать...    Евроремонт              20 18    NaN
#
#               Окна              Санузел Можно с детьми/животными  \
# 0              NaN                  NaN  Можно с детьми, ...
# 1  На улицу и двор  Совмещенный (2),...       Можно с детьми
# 2  На улицу и двор      Совмещенный (3)       Можно с детьми
# 3  На улицу и двор      Совмещенный (3)    Можно с животными
# 4  На улицу и двор      Совмещенный (2)                  NaN
#
#          Дополнительно        Название ЖК Серия дома  Высота потолков, м  \
# 0  Мебель в комната...  Новый Арбат, 2010        NaN                 3.0
# 1  Мебель в комната...        Новый Арбат        NaN                 3.5
# 2  Мебель в комната...        Новый Арбат        NaN                 3.2
# 3  Мебель в комната...                NaN        NaN                 3.2
# 4  Мебель в комната...           The Book        NaN                 3.9
#
#                  Лифт Мусоропровод Ссылка на объявление
# 0  Пасс (4), Груз (1)           Да  https://www.cian...
# 1  Пасс (1), Груз (1)          Нет  https://www.cian...
# 2            Пасс (1)          NaN  https://www.cian...
# 3            Пасс (1)          NaN  https://www.cian...
# 4  Пасс (1), Груз (1)           Да  https://www.cian...

# %%
df = df.drop(columns=['Unnamed: 0'])
df = df.reset_index(drop=True)

# %% [markdown]
# ## таблица уникальных значений в каждой колонке и их количество

# %%
for column in df.columns.tolist(): 
    print (column)
    print (df[column].value_counts(dropna=False))
# Out:
# ID  объявления
# ID  объявления
# 271271157    1
# 271634126    1
# 271173086    1
# 272197456    1
# 273614615    1
#             ..
# 215565511    1
# 274654844    1
# 268679909    1
# 274807525    1
# 274672243    1
# Name: count, Length: 23368, dtype: int64
# Количество комнат
# Количество комнат
# 1                   7917
# 2, Изолированная    4623
# 2                   2591
# 3                   1717
# 3, Изолированная    1583
# NaN                 1041
# 3, Оба варианта      875
# 4                    674
# 2, Смежная           637
# 2, Оба варианта      615
# 4, Оба варианта      253
# 5                    235
# 4, Изолированная     223
# 6                     87
# 3, Смежная            87
# 5, Оба варианта       81
# 5, Изолированная      47
# 6, Оба варианта       31
# 6, Изолированная      17
# 4, Смежная            13
# 1, Изолированная       8
# 1, Оба варианта        4
# 5, Смежная             4
# 6, Смежная             3
# 1, Смежная             2
# Name: count, dtype: int64
# Тип
# Тип
# Квартира    23368
# Name: count, dtype: int64
# Метро
# Метро
# NaN                                     1315
# м. Академическая (10 мин пешком)          41
# м. Водный стадион (5 мин пешком)          40
# м. Приморская (None мин пешком)           35
# м. Щелковская (15 мин пешком)             34
#                                         ...
# м. Юго-Западная (15 мин на машине)         1
# м. Боровское шоссе (4 мин на машине)       1
# м. Боровское шоссе (5 мин на машине)       1
# м. Говорово (2 мин пешком)                 1
# м. Солнцево (5 мин на машине)              1
# Name: count, Length: 5867, dtype: int64
# Адрес
# Адрес
# Москва, Чапаевский переулок, 3                                                                 63
# Москва, улица Василисы Кожиной, 13                                                             46
# Москва, улица 1-я Леонова, 18                                                                  42
# Москва, Мосфильмовская улица, 8                                                                37
# Москва, Гостиничный проезд, 8К1                                                                32
#                                                                                                ..
# Москва, улица Авиаторов, 9к1, ш. Боровское (5 км до МКАД), ш. Киевское (6 км до МКАД)           1
# Москва, улица Авиаторов, 5к3, ш. Боровское (6 км до МКАД), ш. Киевское (7 км до МКАД)           1
# Москва, Солнцевский проспект, 26К1, ш. Боровское (4 км до МКАД), ш. Киевское (7 км до МКАД)     1
# Москва, Солнцевский проспект, 19, ш. Боровское (5 км до МКАД), ш. Киевское (7 км до МКАД)       1
# Москва, Боровский проезд, 11                                                                    1
# Name: count, Length: 12850, dtype: int64
# Площадь, м2
# Площадь, м2
# 40.0/20.0/10.0    224
# 40.0              116
# 45.0/30.0/6.0     110
# 60.0               91
# 45.0               88
#                  ...
# 35.0/16.4/8.0       1
# 38.7/16.5/11.0      1
# 43.1                1
# 52.5/10.0           1
# 90.0/48.2/15.5      1
# Name: count, Length: 11255, dtype: int64
# Дом
# Дом
# 3/5, Кирпичный                322
# 4/5, Кирпичный                296
# 2/5, Кирпичный                255
# 1/5, Кирпичный                232
# 5/5, Кирпичный                231
#                              ...
# 3/36                            1
# 25/42, Монолитный               1
# 4/11, Панельный                 1
# 10/23, Монолитно-кирпичный      1
# 12/25, Блочный                  1
# Name: count, Length: 2565, dtype: int64
# Парковка
# Парковка
# NaN               13417
# наземная           6043
# подземная          2772
# открытая           1017
# многоуровневая      118
# на крыше              1
# Name: count, dtype: int64
# Цена
# Цена
# 40000.0 руб./ За месяц, Залог - 40000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес              1113
# 45000.0 руб./ За месяц, Залог - 45000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес              1072
# 35000.0 руб./ За месяц, Залог - 35000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес               959
# 50000.0 руб./ За месяц, Залог - 50000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес               911
# 55000.0 руб./ За месяц, Залог - 55000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес               678
#                                                                                                                                   ...
# 39999.0 руб./ За месяц, Залог - 1 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес                     1
# 25000.0 руб./ За месяц, Залог - 12000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 1 мес                 1
# 48000.0 руб./ За месяц, Залог - 40000 руб., Коммунальные услуги включены, Срок аренды - На несколько месяцев, Предоплата 1 мес       1
# 39000.0 руб./ За месяц, Залог - 40000 руб., Коммунальные услуги включены, Срок аренды - На несколько месяцев, Предоплата 1 мес       1
# 55000.0 руб./ За месяц, Залог - 50000 руб., Коммунальные услуги включены, Срок аренды - Длительный, Предоплата 2 мес                 1
# Name: count, Length: 3922, dtype: int64
# Телефоны
# Телефоны
# +79819217172    302
# +74954760059    264
# +79652883064    253
# +79681933625    165
# +79651095872    118
#                ...
# +79154383401      1
# +79151173402      1
# +79653825192      1
# +79660611965      1
# +79623641533      1
# Name: count, Length: 13172, dtype: int64
# Описание
# Описание
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    108
# Квартира сдаётся с Яндекс Арендой, а значит всё для вас:\n- без залога;\n- без единоразовой комиссии;\n- с поддержкой от наших специалистов в процессе проживания.\n \nМы можем показать вам квартиру онлайн  это так же детально, как вживую, только вы не тратите время на дорогу и запись возможна на ближайшее время., 14 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    10
# Квартира сдаётся с Яндекс Арендой, а значит всё для вас:\n- без залога;\n- без единоразовой комиссии;\n- с поддержкой от наших специалистов в процессе проживания.\n \nМы можем показать вам квартиру онлайн  это так же детально, как вживую, только вы не тратите время на дорогу и запись возможна на ближайшее время., 17 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     9
# Квартира сдаётся с Яндекс Арендой, а значит всё для вас:\n- без залога;\n- без единоразовой комиссии;\n- с поддержкой от наших специалистов в процессе проживания.\n \nМы можем показать вам квартиру онлайн  это так же детально, как вживую, только вы не тратите время на дорогу и запись возможна на ближайшее время., 16 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     9
# Квартира сдаётся с Яндекс Арендой, а значит всё для вас:\n- без залога;\n- без единоразовой комиссии;\n- с поддержкой от наших специалистов в процессе проживания.\n \nМы можем показать вам квартиру онлайн  это так же детально, как вживую, только вы не тратите время на дорогу и запись возможна на ближайшее время., 15 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     9
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Сдаётся светлая теплая квартира (студия) с балкон и хорошим свежим ремонтом. Есть вся необходимая мебель и техника. На этаже имеется колясочная. Закрытый охраняемый двор.  Вся инфраструктура на территории ЖК ( магазины , кафе, аптеки, салоны красоты), 5 минут пешком до метро Говорово, рядом автобусная остановка до метро Юго-Западня. Так же рядом парк "Мещерский Лес", в котором есть пляж и пруд. Квартира сдается на длительный срок. Аренда от собственника! Без комиссии!, 10 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Сдам однокомнатную квартиру на длительный срок. Метро Солнцево, ЖК "Лучи".\nУкомплектована бытовой техникой и мебелью. Сдача от собственника. Сдам гражданам России -для одного человека или семейной пары без детей и животных.\nРиэлторов прошу не беспокоить., 7 фото                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Рассматриваются квартиранты только славяне и только на длительный срок.\nБез животных.\nИдеальная квартира для двоих. Одна комната изолированная, вторая объединена с кухонной зоной.\nСдается очень уютная и светлая двухкомнатная квартира в экологически чистом районе Москвы. 5 минут пешком до станции метро Солнцево, либо до ж/д станции "Солнечная". \nНесомненным плюсом является отсутствие соседей сверху. Всегда есть парковочные места возле дома. В районе много зелени, через дорогу зона отдыха с прудом, фитнес-центр. В шаговой доступности Мещерский парк. В шаговой доступности имеется несколько школ, детских садов, торгово-развлекательных центров. \nКвартира очень теплая. Сделан качественный капитальный ремонт в теплых тонах. Пластиковые стеклопакеты на окнах, балкон холодный, застеклен. \nНа данный момент квартира сдается без спальной мебели (без дивана и кровати) и телевизора.\nМебель:\n- кухонный гарнитур\n- шкаф для верхней одежды\n- шкаф в спальне\nКомплект техники:\n- встраиваемые холодильник и  ..., 21 фото      1
# Двухкомнатная уютная квартира с видом во внутренний зеленый двор.\nПрихожая со встроенным шкафом. \nКухня - гостиная (20 кв. м) оборудованная всей техникой( электрическая плита, посудомойка, холодильник, чайник).\nСпальня (15 кв. м.)с выходом на лоджию (4.5 кв. м) с мебелью. При спальне есть гардеробная.\nСанузел совмещенный. Гостиная и спальня оборудована кондиционерами Daikin.\nПри выходе из подъезда через дорогу парк с прогулочными дорожкам и освещением. Рядом с домом два магазина пятерочка. В доме, в соседнем подъезде тренажёрный зал. \nПарковаться можно перед подъездами и во дворе. Есть две платные парковки. \nДо метро Солнцево 7-10 мин. пешком. \nСдается на длительный срок. В стоимость аренды входит коммунальные платежи без счетчиков воды и света. Залог в размере 55000 руб. Оплата за первый и последний месяц при заключении договора., 25 фото                                                                                                                                                                            1
# Сдается просторная двухкомнатная квартира ВПЕРВЫЕ! КОММУНАЛЬНЫЕ ПЛАТЕЖИ СКИДКА 50%. Квартира находится в шаговой доступности от двух станций метро: Говорово и Солнцево. Имеется все необходимое для жизни! Кухня оснащена всем жизненно важным для комфортного быта: большой вместительный холодильник, посудомоечная машина, измельчитель для отходов, индукционная плита, духовка, посуда. В квартире в каждой комнате есть кондиционер. В ванной установлен бойлер, за счет чего можно не переживать за сезонное отключение горячей воды. Так же кроме вместительных шкафов для вещей имеется кладовая/гардеробная! Просторная лоджия с большими окнами выходит в тихий и спокойный двор. Рядом с домом: несколько продуктовых магазинов, школы, детские сады и парк с прудом. Удобный съезд на Боровское шоссе. Удобная транспортная доступность до ЛУЧШИХ ВУЗОВ СТРАНЫ: РАНХИГС, МГИМО, РУДН, МГУ!, 16 фото                                                                                                                                                      1
# Name: count, Length: 23078, dtype: int64
# Ремонт
# Ремонт
# Косметический    8499
# Евроремонт       8470
# Дизайнерский     3474
# NaN              2755
# Без ремонта       170
# Name: count, dtype: int64
# Площадь комнат, м2
# Площадь комнат, м2
# NaN               8910
# 20                1620
# 18                 952
# 19                 765
# 17                 284
#                   ...
# 18+10.5              1
# 10-17+12             1
# 22-16-30             1
# 32+13,6-18,7         1
# 26,2+15,5-22,0       1
# Name: count, Length: 3991, dtype: int64
# Балкон
# Балкон
# NaN                       7978
# Балкон (1)                7428
# Лоджия (1)                6007
# Балкон (1), Лоджия (1)     716
# Лоджия (2)                 568
# Балкон (2)                 474
# Балкон (3)                  55
# Лоджия (3)                  45
# Балкон (2), Лоджия (2)      25
# Балкон (1), Лоджия (2)      24
# Балкон (2), Лоджия (1)      20
# Балкон (4)                   6
# Балкон (3), Лоджия (1)       5
# Балкон (1), Лоджия (3)       5
# Лоджия (4)                   5
# Балкон (2), Лоджия (3)       3
# Балкон (1), Лоджия (4)       2
# Балкон (3), Лоджия (3)       1
# Балкон (4), Лоджия (4)       1
# Name: count, dtype: int64
# Окна
# Окна
# Во двор            10870
# NaN                 6613
# На улицу и двор     3295
# На улицу            2590
# Name: count, dtype: int64
# Санузел
# Санузел
# Совмещенный (1)                    10078
# Раздельный (1)                      7158
# NaN                                 2672
# Совмещенный (2)                     1437
# Совмещенный (1), Раздельный (1)      812
# Раздельный (2)                       534
# Совмещенный (3)                      241
# Совмещенный (2), Раздельный (1)      188
# Совмещенный (4)                       77
# Раздельный (3)                        52
# Совмещенный (1), Раздельный (2)       30
# Совмещенный (3), Раздельный (1)       27
# Совмещенный (2), Раздельный (2)       25
# Раздельный (4)                        15
# Совмещенный (3), Раздельный (3)        6
# Совмещенный (4), Раздельный (1)        6
# Совмещенный (4), Раздельный (2)        4
# Совмещенный (1), Раздельный (3)        2
# Совмещенный (2), Раздельный (3)        2
# Совмещенный (2), Раздельный (4)        1
# Совмещенный (3), Раздельный (2)        1
# Name: count, dtype: int64
# Можно с детьми/животными
# Можно с детьми/животными
# Можно с детьми                       10134
# Можно с детьми, Можно с животными     6899
# NaN                                   6096
# Можно с животными                      239
# Name: count, dtype: int64
# Дополнительно
# Дополнительно
# Мебель в комнатах, Мебель на кухне, Ванна, Стиральная машина, Телевизор, Холодильник, Интернет                                       2896
# Мебель в комнатах, Мебель на кухне, Ванна, Стиральная машина, Холодильник, Интернет                                                  1318
# Мебель в комнатах, Мебель на кухне, Ванна, Стиральная машина, Кондиционер, Посудомоечная машина, Телевизор, Холодильник, Интернет    1042
# Мебель в комнатах, Мебель на кухне, Ванна, Стиральная машина, Кондиционер, Телевизор, Холодильник, Интернет                           967
# Мебель в комнатах, Мебель на кухне, Ванна, Стиральная машина, Телевизор, Холодильник, Интернет, Телефон                               887
#                                                                                                                                      ...
# Мебель на кухне, Душевая кабина, Стиральная машина, Кондиционер, Посудомоечная машина, Интернет, Телефон                                1
# Мебель на кухне, Ванна, Кондиционер, Холодильник, Интернет, Телефон                                                                     1
# Мебель на кухне, Ванна, Душевая кабина, Посудомоечная машина, Телевизор, Холодильник, Интернет, Телефон                                 1
# Мебель на кухне, Ванна, Кондиционер                                                                                                     1
# Мебель на кухне, Телевизор, Холодильник, Интернет                                                                                       1
# Name: count, Length: 529, dtype: int64
# Название ЖК
# Название ЖК
# NaN                      17520
# Символ, 2019                61
# Водный, 2015                45
# Квартал на Ленинском        37
# Метрополия, 2021            36
#                          ...
# На Циолковского, 2014        1
# Лучи, 2010                   1
# Лучи, 2018                   1
# В Солнцево, 2013             1
# В Солнцево                   1
# Name: count, Length: 1799, dtype: int64
# Серия дома
# Серия дома
# NaN                      21205
# индивидуальный проект      615
# Индивидуальный проект      139
# П44                         89
# П44Т                        63
#                          ...
# I-447                        1
# 1973                         1
# И-209А (И-209)               1
# II-18-12                     1
# П 44-Т                       1
# Name: count, Length: 394, dtype: int64
# Высота потолков, м
# Высота потолков, м
# NaN     12162
# 2.64     4467
# 3.00     1322
# 2.70     1040
# 2.48      676
#         ...
# 3.41        1
# 3.24        1
# 3.21        1
# 1.20        1
# 3.02        1
# Name: count, Length: 96, dtype: int64
# Лифт
# Лифт
# Пасс (1)               5911
# NaN                    5500
# Пасс (2)               4326
# Пасс (1), Груз (1)     3962
# Пасс (2), Груз (1)     1224
# Пасс (2), Груз (2)      654
# Пасс (3)                636
# Пасс (4)                346
# Пасс (3), Груз (1)      187
# Пасс (1), Груз (2)      185
# Груз (1)                 95
# Пасс (4), Груз (2)       65
# Пасс (4), Груз (1)       64
# Пасс (3), Груз (3)       45
# Пасс (3), Груз (2)       44
# Пасс (4), Груз (4)       28
# Груз (4)                 25
# Груз (2)                 20
# Груз (3)                 15
# Пасс (4), Груз (3)        7
# Пасс (1), Груз (3)        6
# Пасс (6)                  6
# Пасс (2), Груз (3)        3
# Пасс (60)                 2
# Пасс (50)                 2
# Пасс (5), Груз (1)        1
# Пасс (1), Груз (12)       1
# Пасс (8), Груз (8)        1
# Пасс (7)                  1
# Пасс (1), Груз (4)        1
# Пасс (5), Груз (3)        1
# Пасс (2), Груз (4)        1
# Груз (6)                  1
# Груз (8)                  1
# Пасс (5)                  1
# Name: count, dtype: int64
# Мусоропровод
# Мусоропровод
# Да     10897
# NaN    10522
# Нет     1949
# Name: count, dtype: int64
# Ссылка на объявление
# Ссылка на объявление
# https://www.cian.ru/rent/flat/271271157    1
# https://www.cian.ru/rent/flat/271634126    1
# https://www.cian.ru/rent/flat/271173086    1
# https://www.cian.ru/rent/flat/272197456    1
# https://www.cian.ru/rent/flat/273614615    1
#                                           ..
# https://www.cian.ru/rent/flat/215565511    1
# https://www.cian.ru/rent/flat/274654844    1
# https://www.cian.ru/rent/flat/268679909    1
# https://www.cian.ru/rent/flat/274807525    1
# https://www.cian.ru/rent/flat/274672243    1
# Name: count, Length: 23368, dtype: int64

# %% [markdown]
# ## переназывание колонок

# %%
df.columns=['Ad_ID', 'Number_of_rooms', 'Type', 'Metro', 'Address',
 'Area_m2', 'Building', 'Parking', 'Price', 'Phones', 'Description',
 'Renovation', 'Room_area_m2', 'Balcony', 'Windows', 'Bathroom',
 'Children/pets_allowed', 'Additional', 'Residential_complex_name',
 'Building_series', 'Ceiling_height_m', 'Elevator', 'Garbage_chute',
 'Ad_link']
ya_i_columns = ['Ad_ID', 'Description', 'Renovation', 'Room_area_m2', 'Balcony', 'Windows', 'Bathroom', 'Children/pets_allowed']

# %%
# Обработать колонки:
# Description	
# (+) Renovation	
# (+) Room_area_m2	
# (+) Balcony	
# (+) Windows	
# (+) Bathroom	
# (+) Children/pets_allowed
# Очистить от NaN
# Добавить Dummy-кодирование 

def extract_numbers(text):
    if pd.isna(text):
        return []
    numbers_str = re.findall(r'\d+(?:[.,]\d+)?', str(text))
    return [float(x.replace(',', '.')) for x in numbers_str]

def sum_func(text):
    if pd.isna(text):
        return 0
    numbers = re.findall(r'\((\d+)\)', text)
    return sum(int(num) for num in numbers)

ya_i_df = df[ya_i_columns]

ya_i_df['Renovation'] = ya_i_df['Renovation']

ya_i_df['Room_area_m2'] = ya_i_df['Room_area_m2'].apply(extract_numbers)

ya_i_df['Balcony'] = ya_i_df['Balcony'].str.replace(r'\s*\(\d+\)', '', regex=True)
ya_i_df['Balcony_count'] = ya_i_df['Balcony'].apply(sum_func)

ya_i_df['Bathroom'] = ya_i_df['Bathroom'].str.replace(r'\s*\(\d+\)', '', regex=True)
ya_i_df['Bathroom_count'] = ya_i_df['Bathroom'].apply(sum_func)

ya_i_df['Description']

ya_i_df['Renovation'].unique()
# Out:
# <StringArray>
# ['Дизайнерский', 'Евроремонт', 'Косметический', nan, 'Без ремонта']
# Length: 5, dtype: str

# %%
df['Renovation'] = df['Renovation']

df['Room_area_m2'] = df['Room_area_m2'].apply(extract_numbers)

df['Balcony'] = df['Balcony'].str.replace(r'\s*\(\d+\)', '', regex=True)
df['Balcony_count'] = df['Balcony'].apply(sum_func)

df['Bathroom'] = df['Bathroom'].str.replace(r'\s*\(\d+\)', '', regex=True)
df['Bathroom_count'] = df['Bathroom'].apply(sum_func)

# %%
df['Number_of_rooms_int'] = df['Number_of_rooms'].apply(lambda x : defs.cutter(x,','))
df['Type of room'] = df['Number_of_rooms'].apply(lambda x : defs.cutter(x,',', index_start=1, index_end= None))

# %%
df= df.drop('Number_of_rooms', axis=1)

# %%
df['extra_money'] = df['Price'].apply(lambda x: defs.cutter(x,'/', index_start=1, index_end = None))
df['Price'] = df['Price'].apply(lambda x: defs.cutter(x,'/'))

# %%
df['Price']=df['Price'].apply(defs.re_money)

# %%
df['Full_area']= df['Area_m2'].apply(lambda x: defs.cutter(x,'/')).astype(float)
df['Rooms_area'] = df['Area_m2'].apply(lambda x: x.split('/')[1:] if len(x.split('/'))>1 else None)
df=df.drop('Area_m2', axis=1)

# %%
df['Float_floor']= df["Building"].apply(lambda x: defs.extract_pattern(x, pattern = r'\d+/\d+')).apply(lambda x: defs.cutter(x, '/'))
df['Height_building']= df["Building"].apply(lambda x: defs.extract_pattern(x, pattern = r'\d+/\d+')).apply(lambda x: defs.cutter(x, '/', index_start=1, index_end=None))
df['Building_type'] = df['Building'].apply(lambda x: defs.cutter(x, ',', index_start=1, index_end=None))

# %%
df = df.drop('Building', axis=1)

# %%
df
# Out:
#            Ad_ID      Type                Metro              Address  \
# 0      271271157  Квартира  м. Смоленская (9...  Москва, улица Но...
# 1      271634126  Квартира  м. Смоленская (8...  Москва, улица Но...
# 2      271173086  Квартира  м. Смоленская (7...  Москва, улица Но...
# 3      272197456  Квартира  м. Смоленская (3...  Москва, переулок...
# 4      273614615  Квартира  м. Арбатская (7 ...  Москва, улица Но...
# ...          ...       ...                  ...                  ...
# 23363  215565511  Квартира  м. Говорово (8 м...  Москва, Боровско...
# 23364  274654844  Квартира  м. Солнцево (7 м...  Москва, Производ...
# 23365  268679909  Квартира  м. Солнцево (6 м...  Москва, Боровски...
# 23366  274807525  Квартира  м. Солнцево (11 ...  Москва, улица Бо...
# 23367  274672243  Квартира  м. Говорово (10 ...  Москва, улица Бо...
#
#          Parking     Price               Phones          Description  \
# 0      подземная  500000.0         +79166369231  Без комиссии для...
# 1      подземная  500000.0         +79850608590  Лот 93107. Елена...
# 2      подземная  500000.0  +79672086536, +7...  ID 36380:  Шикар...
# 3      подземная  400000.0  +79660342340, +7...  ID 31618:  Экскл...
# 4            NaN  225000.0         +79852432860  Лот 111542. Тать...
# ...          ...       ...                  ...                  ...
# 23363        NaN   42000.0         +79154383401  Сдаётся светлая ...
# 23364        NaN   45000.0         +79151173402  Сдам однокомнатн...
# 23365        NaN   50000.0         +79653825192  Рассматриваются ...
# 23366   наземная   55000.0         +79660611965  Двухкомнатная ую...
# 23367        NaN   57000.0         +79623641533  Сдается просторн...
#
#           Renovation         Room_area_m2 Balcony          Windows  \
# 0       Дизайнерский                   []     NaN              NaN
# 1       Дизайнерский  [25.0, 25.0, 20....     NaN  На улицу и двор
# 2         Евроремонт                   []     NaN  На улицу и двор
# 3         Евроремонт  [14.0, 42.0, 20....     NaN  На улицу и двор
# 4         Евроремонт         [20.0, 18.0]     NaN  На улицу и двор
# ...              ...                  ...     ...              ...
# 23363     Евроремонт                   []  Балкон              NaN
# 23364     Евроремонт                   []  Лоджия          Во двор
# 23365   Дизайнерский                   []  Балкон  На улицу и двор
# 23366     Евроремонт                   []  Лоджия          Во двор
# 23367  Косметический   [26.2, 15.5, 22.0]  Лоджия          Во двор
#
#                   Bathroom Children/pets_allowed           Additional  \
# 0                      NaN  Можно с детьми, ...   Мебель в комната...
# 1      Совмещенный, Раз...       Можно с детьми   Мебель в комната...
# 2              Совмещенный       Можно с детьми   Мебель в комната...
# 3              Совмещенный    Можно с животными   Мебель в комната...
# 4              Совмещенный                  NaN   Мебель в комната...
# ...                    ...                  ...                   ...
# 23363          Совмещенный                  NaN   Мебель в комната...
# 23364          Совмещенный                  NaN   Мебель в комната...
# 23365          Совмещенный       Можно с детьми   Мебель на кухне,...
# 23366  Совмещенный, Раз...                  NaN   Мебель в комната...
# 23367           Раздельный  Можно с детьми, ...   Мебель в комната...
#
#       Residential_complex_name Building_series  Ceiling_height_m  \
# 0        Новый Арбат, 2010                 NaN              3.00
# 1              Новый Арбат                 NaN              3.50
# 2              Новый Арбат                 NaN              3.20
# 3                      NaN                 NaN              3.20
# 4                 The Book                 NaN              3.90
# ...                    ...                 ...               ...
# 23363        Мещерский лес                 NaN               NaN
# 23364                 Лучи                 NaN               NaN
# 23365                  NaN                 NaN               NaN
# 23366                  NaN                 NaN              2.65
# 23367                  NaN                 NaN               NaN
#
#                  Elevator Garbage_chute              Ad_link  Balcony_count  \
# 0      Пасс (4), Груз (1)            Да  https://www.cian...              0
# 1      Пасс (1), Груз (1)           Нет  https://www.cian...              0
# 2                Пасс (1)           NaN  https://www.cian...              0
# 3                Пасс (1)           NaN  https://www.cian...              0
# 4      Пасс (1), Груз (1)            Да  https://www.cian...              0
# ...                   ...           ...                  ...            ...
# 23363  Пасс (1), Груз (1)           NaN  https://www.cian...              0
# 23364  Пасс (1), Груз (1)           NaN  https://www.cian...              0
# 23365                 NaN           NaN  https://www.cian...              0
# 23366            Пасс (3)            Да  https://www.cian...              0
# 23367            Пасс (3)            Да  https://www.cian...              0
#
#        Bathroom_count Number_of_rooms_int   Type of room          extra_money  \
# 0                   0                   4                  За месяц, Залог...
# 1                   0                   4                  За месяц, Залог...
# 2                   0                   4   Оба варианта   За месяц, Залог...
# 3                   0                   4   Оба варианта   За месяц, Залог...
# 4                   0                   2                  За месяц, Залог...
# ...               ...                 ...            ...                  ...
# 23363               0                 NaN            NaN   За месяц, Залог...
# 23364               0                   1                  За месяц, Залог...
# 23365               0                   2   Оба варианта   За месяц, Залог...
# 23366               0                   2                  За месяц, Залог...
# 23367               0                   2   Оба варианта   За месяц, Залог...
#
#        Full_area    Rooms_area Float_floor Height_building  \
# 0          200.0        [20.0]           5              16
# 1          198.0  [95.0, 18.0]           5              16
# 2          200.0  [116.0, 4.0]           5              16
# 3          170.0  [95.0, 17.0]           5               6
# 4           58.0   [38.0, 5.0]          12              26
# ...          ...           ...         ...             ...
# 23363       35.0   [16.4, 8.0]          10              14
# 23364       38.7  [16.5, 11.0]           5              18
# 23365       43.1          None           5               5
# 23366       52.5        [10.0]           8              23
# 23367       90.0  [48.2, 15.5]           6              23
#
#              Building_type
# 0               Монолитный
# 1       Монолитно-кирпи...
# 2
# 3
# 4                Панельный
# ...                    ...
# 23363
# 23364           Монолитный
# 23365            Кирпичный
# 23366           Монолитный
# 23367            Панельный
#
# [23368 rows x 31 columns]

# %%
df = df[~df['Address'].str.lower().str.startswith('санкт-петербург', na=False)]

# %% [markdown]
# ### Garbage_chute

# %%
# df["Garbage_chute"] = df["Garbage_chute"].replace({"Да":1, "Нет":0})
df["Garbage_chute(yes)"] = df["Garbage_chute"].eq("Да")
df["Garbage_chute(no)"] = df["Garbage_chute"].eq("Нет")

df["Garbage_chute(yes)"] = df["Garbage_chute(yes)"].astype(int)
df["Garbage_chute(no)"] = df["Garbage_chute(no)"].astype(int)

# %% [markdown]
# ### Ceiling_height_m

# %%
df.loc[df["Ceiling_height_m"] > 100, "Ceiling_height_m"] /= 100
df.loc[df["Ceiling_height_m"] > 24.9, "Ceiling_height_m"] /= 10

df["Ceiling_height_m"] = df["Ceiling_height_m"][(df["Ceiling_height_m"] > 2.4) & (df["Ceiling_height_m"] < 6)]

# %% [markdown]
# ### Elevator

# %%
df["pass_elev"] = df["Elevator"].str.extract(r"Пасс\s*\((\d+)\)").fillna(0).astype(int)
df["cargo_elev"] = df["Elevator"].str.extract(r"Груз\s*\((\d+)\)").fillna(0).astype(int)
df["elevator_more_2"] = (df["pass_elev"]+df["cargo_elev"] >= 2).astype(int)

# %% [markdown]
# ### f

# %%
df = df.drop(["Elevator", "Residential_complex_name", "Building_series", "Garbage_chute"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20340 entries, 0 to 23367
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ad_ID                  20340 non-null  int64
#  1   Type                   20340 non-null  str
#  2   Metro                  19391 non-null  str
#  3   Address                20340 non-null  str
#  4   Parking                8748 non-null   str
#  5   Price                  20340 non-null  float64
#  6   Phones                 20340 non-null  str
#  7   Description            20340 non-null  str
#  8   Renovation             17872 non-null  str
#  9   Room_area_m2           20340 non-null  object
#  10  Balcony                13478 non-null  str
#  11  Windows                14963 non-null  str
#  12  Bathroom               18147 non-null  str
#  13  Children/pets_allowed  15275 non-null  str
#  14  Additional             20047 non-null  str
#  15  Ceiling_height_m       10573 non-null  float64
#  16  Ad_link                20340 non-null  str
#  17  Balcony_count          20340 non-null  int64
#  18  Bathroom_count         20340 non-null  int64
#  19  Number_of_rooms_int    19716 non-null  str
#  20  Type of room           19716 non-null  str
#  21  extra_money            20340 non-null  str
#  22  Full_area              20340 non-null  float64
#  23  Rooms_area             17521 non-null  object
#  24  Float_floor            20340 non-null  str
#  25  Height_building        20340 non-null  str
#  26  Building_type          20340 non-null  str
#  27  Garbage_chute(yes)     20340 non-null  int64
#  28  Garbage_chute(no)      20340 non-null  int64
#  29  pass_elev              20340 non-null  int64
#  30  cargo_elev             20340 non-null  int64
#  31  elevator_more_2        20340 non-null  int64
# dtypes: float64(3), int64(8), object(2), str(19)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Распределение количества кваритир по количеству комнат

# %%
fig, ax = plt.subplots()
sns.barplot(data = df.groupby('Number_of_rooms_int', as_index=False).count() , x ='Number_of_rooms_int', y = 'Ad_ID' )
ax.set_xlabel('Количество комнат')
ax.set_ylabel('Количество кваритр')
plt.show()
